# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use("main.mplstyle")

plt.scatter(np.random.rand(100), np.random.rand(100))
plt.title("Sorted Power-Law Distributed Values for Apple and Orange")
plt.show()
